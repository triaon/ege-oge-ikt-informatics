# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
import numba
from numba import jit, prange

# %%
@jit(nopython=True)
def f():
    m = 950_000_000
    result = list()
    while len(result) < 5:
        m += 2
        # div2 = 1
        div2 = [m]
        # print(m)
        for i in prange(2, m+1, 2):
            if m % i == 0:
                if (m / i) % 2 == 0:
                    # div2 += 1
                    div2.append(m / i)
                if i % 2 == 0 and i != (m / i):
                    # div2 += 1
                    div2.append(i)
        # if div2 % 2 == 1:
        if len(div2) % 2 == 1:
            result.append(m - 950_000_000)
            # print(m)
            # print(result)
            # print(div2)
    print(*result)

# %%
f()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/3782956317.py in <module>
# ----> 1 f()
#
# ~\AppData\Roaming\Python\Python38\site-packages\numba\core\dispatcher.py in _compile_for_args(self, *args, **kws)
#     413                 e.patch_message(msg)
#     414
# --> 415             error_rewrite(e, 'typing')
#     416         except errors.UnsupportedError as e:
#     417             # Something unsupported is present in the user code, add help info
#
# ~\AppData\Roaming\Python\Python38\site-packages\numba\core\dispatcher.py in error_rewrite(e, issue_type)
#     356                 raise e
#     357             else:
# --> 358                 reraise(type(e), e, None)
#     359
#     360         argtypes = []
#
# ~\AppData\Roaming\Python\Python38\site-packages\numba\core\utils.py in reraise(tp, value, tb)
#      78         value = tp()
#      79     if value.__traceback__ is not tb:
# ---> 80         raise value.with_traceback(tb)
#      81     raise value
#      82
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Internal error at <numba.core.typeinfer.PrintConstraint object at 0x0000023233232C70>.
# *args in function call should be a tuple, got list(int64)<iv=None>
# Enable logging at debug level for details.
#
# File "..\..\..\AppData\Local\Temp\ipykernel_12848\3738608123.py", line 24:
# <source missing, REPL/exec in use?>

# %%
# m = 950_000_000
m = 0
result = list()
while len(result) < 5:
    m += 2
    # div2 = 1
    div2 = [m]
    # print(m)
    for i in range(2, m + 1, 2):
        if m % i == 0:
            if (m / i) % 2 == 0:
                # div2 += 1
                div2.append(m / i)
            if i % 2 == 0 and i != (m / i):
                # div2 += 1
                div2.append(i)
    # if div2 % 2 == 1:
    if len(div2) % 2 == 1:
#         result.append(m - 950_000_000)
        print(m)
        # print(m)
        # print(result)
        # print(div2)
print(*result)
# Out:
# 4
# 6
# 10
# 12
# 14
# 16
# 20
# 22
# 24
# 26
# 28
# 30
# 34
# 36
# 38
# 40
# 42
# 44
# 46
# 48
# 52
# 54
# 56
# 58
# 60
# 62
# 64
# 66
# 68
# 70
# 74
# 76
# 78
# 80
# 82
# 84
# 86
# 88
# 90
# 92
# 94
# 96
# 100
# 102
# 104
# 106
# 108
# 110
# 112
# 114
# 116
# 118
# 120
# 122
# 124
# 126
# 130
# 132
# 134
# 136
# 138
# 140
# 142
# 144
# 146
# 148
# 150
# 152
# 154
# 156
# 158
# 160
# 164
# 166
# 168
# 170
# 172
# 174
# 176
# 178
# 180
# 182
# 184
# 186
# 188
# 190
# 192
# 194
# 196
# 198
# 202
# 204
# 206
# 208
# 210
# 212
# 214
# 216
# 218
# 220
# 222
# 224
# 226
# 228
# 230
# 232
# 234
# 236
# 238

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/3743651912.py in <module>
#       8     # print(m)
#       9     for i in range(2, m + 1, 2):
# ---> 10         if m % i == 0:
#      11             if (m / i) % 2 == 0:
#      12                 # div2 += 1
#
# KeyboardInterrupt:

# %%
m = 950_000_000
result = list()
while len(result) < 5:
    m += 2
    div2 = []
    counter2 = 0
    m2 = m
    while m2 % 2 == 0:
        m2 //= 2
        counter2 += 1
    if counter2 % 2 == 1:
        div2 = [m]
        for i in range(2, int(m**0.5) + 1):
            if m % i == 0:
                if (m // i) % 2 == 0:
                    div2.append(m // i)
                if i % 2 == 0 and i != (m // i):
                    div2.append(i)

    if len(div2) % 2 == 1:
        result.append(m)

print(*result)
# Out:
# 950044050 2 316681350.0 190008810.0 6 105560450.0 10 63336270.0 18 38001762.0 30 21112090.0 50 12667254.0 90 150 4222418.0 450 653850.0 2906 217950.0 130770.0 8718 72650.0 14530 43590.0 26154
# 950131232 475065616.0 2 237532808.0 4 118766404.0 8 59383202.0 16 32 174368.0 87184.0 10898 43592.0 21796
# 950218418 2 13383358.0 142 3095174.0 614 188498.0 10082 43594.0
# 950305608 475152804.0 2 316768536.0 237576402.0 4 158384268.0 6 135757944.0 8 105589512.0 79192134.0 12 67878972.0 14 52794756.0 18 45252648.0 24 35196504.0 33939486.0 28 26397378.0 36 22626324.0 42 19393992.0 17598252.0 54 56 15084216.0 72 11732168.0 11313162.0 84 9696996.0 98 8799126.0 108 7542108.0 126 6464664.0 5866084.0 162 168 5493096.0 5028072.0 4848498.0 196 216 3771054.0 252 3232332.0 294 2933042.0 324 2746548.0 346 2514036.0 378 392 2154888.0 504 1831032.0 1676024.0 1616166.0 588 648 1373274.0 692 1257018.0 756 1077444.0 882 915516.0 1038 838012.0 1134 1176 784728.0 718296.0 1384 1512 610344.0 538722.0 1764 457758.0 2076 419006.0 2268 392364.0 2422 359148.0 2646 305172.0 3114 3528 261576.0 239432.0 4152 4536 203448.0 196182.0 4844 179574.0 5292 152586.0 6228 130788.0 7266 119716.0 7938 112104.0 101724.0 9342 9688 10584 87192.0 12456 67816.0 65394.0 14532 59858.0 15876 56052.0 16954 50862.0 18684 43596.0 21798 37368.0 33908.0 28026 29064 31752.0
# 950392802 2 43598.0
# [950044050, 950131232, 950218418, 950305608, 950392802]

# %%
m = 950_000_000
result = list()
while len(result) < 5:
    m += 2
    # div2 = 1
    div2 = [m]
    # print(m)
    for i in range(2, int(m ** 0.5) + 1, 2):
        if m % i == 0:
            if (m / i) % 2 == 0:
                # div2 += 1
                div2.append(m / i)
            if i % 2 == 0 and i != (m / i):
                # div2 += 1
                div2.append(i)
    # if div2 % 2 == 1:
    if len(div2) % 2 == 1:
        result.append(m - 950_000_000)
        # print(m)
        # print(result)
        # print(div2)
print(*result)

# %% [markdown]
# ---

# %%
def k(n):
    for i in range(1,n+1):
        yi
